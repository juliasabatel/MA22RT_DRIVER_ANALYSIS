# %% [markdown]
# # LIBRARY IMPORTATION

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.collections import LineCollection
from matplotlib import cm

import warnings
warnings.filterwarnings('ignore')  

pd.set_option('display.max_columns', None)

# %% [markdown]
# # DATABASE IMPORTATION

# %%
#CARRERA COMPLETA A
A_RACE = pd.read_csv('../Desktop/MA22RT_PROJECT/complete_database_pilots_copy/FSS_22_ENDURANCE_ALBA copia.csv', encoding='latin1')

# %%
#CARRERA COMPLETA D
D_RACE = pd.read_csv('../Desktop/MA22RT_PROJECT/database_no_laps/copy_database_pilots/DAVID_Endurance_FSS_copia.csv', encoding='latin1', sep=';')

# %%
A_LAP1 = pd.read_csv('../Desktop/MA22RT_PROJECT/laps_database/DIVISION_copia/FSS_ENDURANCE_ALBA_LAP_1.csv', encoding='latin1', sep=';')

# %%
A_LAP2 = pd.read_csv('../Desktop/MA22RT_PROJECT/laps_database/DIVISION_copia/FSS_ENDURANCE_ALBA_LAP_2.csv', encoding='latin1', sep=';')

# %%
A_LAP3 = pd.read_csv('../Desktop/MA22RT_PROJECT/laps_database/DIVISION_copia/FSS_ENDURANCE_ALBA_LAP_3.csv', encoding='latin1', sep=';')

# %%
A_LAP4 = pd.read_csv('../Desktop/MA22RT_PROJECT/laps_database/DIVISION_copia/FSS_ENDURANCE_ALBA_LAP_4.csv', encoding='latin1', sep=';')

# %%
A_LAP5 = pd.read_csv('../Desktop/MA22RT_PROJECT/laps_database/DIVISION_copia/FSS_ENDURANCE_ALBA_LAP_5.csv', encoding='latin1', sep=';')

# %%
A_LAP6 = pd.read_csv('../Desktop/MA22RT_PROJECT/laps_database/DIVISION_copia/FSS_ENDURANCE_ALBA_LAP_6.csv', encoding='latin1', sep=';')

# %%
A_LAP7 = pd.read_csv('../Desktop/MA22RT_PROJECT/laps_database/DIVISION_copia/FSS_ENDURANCE_ALBA_LAP_7.csv', encoding='latin1', sep=';')

# %%
A_LAP8 = pd.read_csv('../Desktop/MA22RT_PROJECT/laps_database/DIVISION_copia/FSS_ENDURANCE_ALBA_LAP_8.csv', encoding='latin1', sep=';')

# %%
D_LAP1 = pd.read_csv('../Desktop/MA22RT_PROJECT/laps_database/DIVISION_copia/FSS_ENDURANCE_DAVID_LAP_1.csv', encoding='latin1', sep=';')

# %%
D_LAP2 = pd.read_csv('../Desktop/MA22RT_PROJECT/laps_database/DIVISION_copia/FSS_ENDURANCE_DAVID_LAP_2.csv', encoding='latin1', sep=';')

# %%
D_LAP3 = pd.read_csv('../Desktop/MA22RT_PROJECT/laps_database/DIVISION_copia/FSS_ENDURANCE_DAVID_LAP_3.csv', encoding='latin1', sep=';')

# %%
D_LAP4 = pd.read_csv('../Desktop/MA22RT_PROJECT/laps_database/DIVISION_copia/FSS_ENDURANCE_DAVID_LAP_4.csv', encoding='latin1', sep=';')

# %%
D_LAP5 = pd.read_csv('../Desktop/MA22RT_PROJECT/laps_database/DIVISION_copia/FSS_ENDURANCE_DAVID_LAP_5.csv', encoding='latin1', sep=';')

# %%
D_LAP6 = pd.read_csv('../Desktop/MA22RT_PROJECT/laps_database/DIVISION_copia/FSS_ENDURANCE_DAVID_LAP_6.csv', encoding='latin1', sep=';')

# %%
D_LAP7 = pd.read_csv('../Desktop/MA22RT_PROJECT/laps_database/DIVISION_copia/FSS_ENDURANCE_DAVID_LAP_7.csv', encoding='latin1', sep=';')

# %%
D_LAP8 = pd.read_csv('../Desktop/MA22RT_PROJECT/laps_database/DIVISION_copia/FSS_ENDURANCE_DAVID_LAP_8.csv', encoding='latin1', sep=';')

# %% [markdown]
# # EXPLORATION DATA

# %%
#Ver vuelta rápida, highlights de la carrera

# %%
#Race driver A

# %%
A_RACE.head()
# Out:
#    Time  Distance  Logger Temperature  AccelerometerX  AccelerometerY  \
# 0  0.00     0.000           33.687458        0.336049       -0.030920
# 1  0.05     0.001           33.687458        0.280212       -0.037097
# 2  0.10     0.001           33.687458        0.217850       -0.046059
# 3  0.15     0.002           33.687458        0.153605       -0.055294
# 4  0.20     0.003           33.687458        0.078337       -0.067040
#
#    AccelerometerZ     GyroX     GyroY     GyroZ  Int Batt Voltage  \
# 0       -1.106257  0.126529 -0.397233 -0.057876          3.829999
# 1       -1.084871  0.029263 -0.612686 -0.209471          3.829999
# 2       -1.062477 -0.122091 -0.709052 -0.514913          3.830011
# 3       -1.038093 -0.272904 -0.747262 -0.929335          3.830074
# 4       -1.010092 -0.422874 -0.846158 -1.397355          3.830161
#
#            RPM  Calculated_Gear  GPS_Speed  GPS_Nsat  GPS_LatAcc  GPS_LonAcc  \
# ...

# %%
A_RACE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14822 entries, 0 to 14821
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time                14822 non-null  float64
#  1   Distance            14822 non-null  float64
#  2   Logger Temperature  14822 non-null  float64
#  3   AccelerometerX      14822 non-null  float64
#  4   AccelerometerY      14822 non-null  float64
#  5   AccelerometerZ      14822 non-null  float64
#  6   GyroX               14822 non-null  float64
#  7   GyroY               14822 non-null  float64
#  8   GyroZ               14822 non-null  float64
#  9   Int Batt Voltage    14822 non-null  float64
#  10  RPM                 14822 non-null  float64
#  11  Calculated_Gear     14822 non-null  float64
#  12  GPS_Speed           14822 non-null  float64
#  13  GPS_Nsat            14822 non-null  float64
#  14  GPS_LatAcc          14822 non-null  float64
# ...

# %%
A_RACE.GPS_Speed.max() #driver A punto mas rápido
# Out:
# 84.686005

# %%
D_RACE.GPS_Speed.max() #driver D punto mas rapido
# Out:
# '92.267.006'

# %%
A_RACE.GPS_Speed.mean() #Velocidad media
# Out:
# 53.7969642098909

# %%
#D_RACE.GPS_Speed no me saca la media

# %% [markdown]
# # VELOCIDAD MEDIA X VUELTAS

# %%
A_LAP1.AccelerometerX.mean()
# Out:
# 0.005823356220960235

# %%
A_RACE.GPS_Speed.mean()#MEDIA DE VELOCIDAD
# Out:
# 53.7969642098909

# %%
def funcion(x):
    
    try:
        return float(x)
    except:
        x=float('.'.join(x.split('.')[:2]))
        return x

# %%
s='1.060.000'

float('.'.join(s.split('.')[:2]))
# Out:
# 1.06

# %%
D_RACE.GPS_Speed.apply(funcion).mean() #VELOCIDAD MEDIA DAVID
# Out:
# 51.46095702910331

# %%
for e in D_RACE.GPS_Speed:
    if type(e)==str:
        print(e)
# Out:
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# 0.000000
# ...

# %%
for e in D_RACE.GPS_Speed:
    if type(e) != str:
        print(e)

# %% [markdown]
# # Vuelta rápida D

# %%
D_LAP1.GPS_Speed.apply(funcion).mean()
# Out:
# 53.38383627608346

# %%
D_LAP2.GPS_Speed.apply(funcion).mean()
# Out:
# 55.14320674405746

# %%
D_LAP3.GPS_Speed.apply(funcion).mean()
# Out:
# 57.36532968929807

# %%
D_LAP4.GPS_Speed.apply(funcion).mean()
# Out:
# 57.66869595375731

# %%
D_LAP5.GPS_Speed.apply(funcion).mean()
# Out:
# 57.735769809138226

# %%
D_LAP6.GPS_Speed.apply(funcion).mean()
# Out:
# 56.40750849377124

# %%
D_LAP7.GPS_Speed.apply(funcion).mean()
# Out:
# 52.279126442812334

# %%
D_LAP8.GPS_Speed.apply(funcion).mean() #vuelta más rápida de D
# Out:
# 58.75662779740874

# %% [markdown]
# # VUELTA RÁPIDA A

# %%
A_LAP1.GPS_Speed.apply(funcion).mean()
# Out:
# 51.41360660815696

# %%
A_LAP2.GPS_Speed.apply(funcion).mean()
# Out:
# 53.51814002145921

# %%
A_LAP3.GPS_Speed.apply(funcion).mean()
# Out:
# 54.36628524768649

# %%
A_LAP4.GPS_Speed.apply(funcion).mean()
# Out:
# 50.4368458038423

# %%
A_LAP5.GPS_Speed.apply(funcion).mean() #VUELTA RAPIDA A
# Out:
# 56.26068361581923

# %%
A_LAP6.GPS_Speed.apply(funcion).mean()
# Out:
# 55.15165005537092

# %%
A_LAP7.GPS_Speed.apply(funcion).mean()
# Out:
# 55.817476163768966

# %%
A_LAP8.GPS_Speed.apply(funcion).mean()
# Out:
# 53.97221656740669

# %% [markdown]
# # Limpieza vuelta rápida A

# %%
#vuelta rápida de A es LAP5

# %%
A_LAP5.head()
# Out:
#    Time  Distance Logger Temperature  AccelerometerX AccelerometerY  \
# 0  0.00     0.000         31.857.067       -0.354309      -0.119869
# 1  0.05     0.001         31.858.870       -0.412061      -0.128056
# 2  0.10     0.002         31.860.674       -0.454671      -0.130070
# 3  0.15     0.003         31.862.476       -0.489577      -0.129646
# 4  0.20     0.004         31.864.281       -0.522539      -0.122892
#
#   AccelerometerZ      GyroX       GyroY       GyroZ Int Batt Voltage  \
# 0      -0.877741  -0.591255  -2.063.972  -2.258.865        3.815.367
# 1      -0.855396  -0.500037  -1.943.496  -2.134.022        3.815.464
# 2      -0.836786  -0.444293  -1.733.240  -1.902.171        3.815.562
# 3      -0.820175  -0.418955  -1.510.336  -1.623.387        3.815.659
# 4      -0.804771  -0.429090  -1.352.375  -1.333.338        3.815.756
#
#              RPM Calculated_Gear   GPS_Speed    GPS_Nsat GPS_LatAcc  \
# 0  9.161.995.117       4.000.000  70.110.001  15.000.000  -0.094833
# ...

# %%
A_LAP5.Time #es float lo dejamos asi
# Out:
# 0        0.000
# 1        0.050
# 2        0.100
# 3        0.150
# 4        0.200
#          ...
# 1765    88.250
# 1766    88.300
# 1767    88.350
# 1768    88.400
# 1769    88.441
# Name: Time, Length: 1770, dtype: float64

# %%
A_LAP5.Distance
# Out:
# 0       0.000
# 1       0.001
# 2       0.002
# 3       0.003
# 4       0.004
#         ...
# 1765    1.378
# 1766    1.379
# 1767    1.380
# 1768    1.381
# 1769    1.382
# Name: Distance, Length: 1770, dtype: float64

# %%
#hay que renombrar columnas para poder seguir trabajando con ellas

# %%
A_LAP5.rename(columns={'Logger Temperature':'Logger_Temperature',
                        'Int Batt Voltage':'Int_Batt_Voltage'},
               inplace=True)
A_LAP5.columns
# Out:
# Index(['Time', 'Distance', 'Logger_Temperature', 'AccelerometerX',
#        'AccelerometerY', 'AccelerometerZ', 'GyroX', 'GyroY', 'GyroZ',
#        'Int_Batt_Voltage', 'RPM', 'Calculated_Gear', 'GPS_Speed', 'GPS_Nsat',
#        'GPS_LatAcc', 'GPS_LonAcc', 'GPS_Slope', 'GPS_Heading', 'GPS_Gyro',
#        'GPS_Altitude', 'GPS_PosAccuracy', 'GPS_SpdAccuracy', 'GPS_Latitude',
#        'GPS_Longitude', 'GPS_Elevation'],
#       dtype='object')

# %%
A_LAP5.Logger_Temperature #es un objeto, tenemos que cambiarlo.
# Out:
# 0       31.857.067
# 1       31.858.870
# 2       31.860.674
# 3       31.862.476
# 4       31.864.281
#            ...
# 1765    31.332.495
# 1766    31.335.361
# 1767    31.338.228
# 1768    31.341.095
# 1769    31.343.447
# Name: Logger_Temperature, Length: 1770, dtype: object

# %%
#creamos una lista para limpiar y luego incluir valores

lst=[]

for x in A_LAP5.Logger_Temperature:
    
    lst.append(float('.'.join(x.split('.')[:2])))
lst[:10]
# Out:
# [31.857, 31.858, 31.86, 31.862, 31.864, 31.866, 31.867, 31.869, 31.871, 31.873]

# %%
A_LAP5['Logger_Temperature']=lst

# %%
A_LAP5.Logger_Temperature #ya tenemos la columna en float
# Out:
# 0       31.857
# 1       31.858
# 2       31.860
# 3       31.862
# 4       31.864
#          ...
# 1765    31.332
# 1766    31.335
# 1767    31.338
# 1768    31.341
# 1769    31.343
# Name: Logger_Temperature, Length: 1770, dtype: float64

# %%
A_LAP5.AccelerometerX #object lo dejamos asi
# Out:
# 0      -0.354309
# 1      -0.412061
# 2      -0.454671
# 3      -0.489577
# 4      -0.522539
#           ...
# 1765    0.344260
# 1766    0.241562
# 1767    0.118076
# 1768   -0.022231
# 1769   -0.143418
# Name: AccelerometerX, Length: 1770, dtype: float64

# %%
A_LAP5.AccelerometerY # crear lista y reemplazarla
# Out:
# 0       -0.119869
# 1       -0.128056
# 2       -0.130070
# 3       -0.129646
# 4       -0.122892
#           ...
# 1765    -0.041210
# 1766    -0.048349
# 1767    -0.057280
# 1768    -0.072207
# 1769    -0.086218
# Name: AccelerometerY, Length: 1770, dtype: object

# %%
#creamos una lista para limpiar y luego incluir valores

lst1=[]

for x in A_LAP5.AccelerometerY:
    
    lst1.append(float('.'.join(x.split('.')[:2])))
lst1[:10]
# Out:
# [-0.119869,
#  -0.128056,
#  -0.13007,
#  -0.129646,
#  -0.122892,
#  -0.11051,
#  -0.090621,
#  -0.063763,
#  -0.033089,
#  -0.000532]

# %%
A_LAP5['AccelerometerY']=lst1

# %%
A_LAP5.AccelerometerY #ya esta limpio
# Out:
# 0      -0.119869
# 1      -0.128056
# 2      -0.130070
# 3      -0.129646
# 4      -0.122892
#           ...
# 1765   -0.041210
# 1766   -0.048349
# 1767   -0.057280
# 1768   -0.072207
# 1769   -0.086218
# Name: AccelerometerY, Length: 1770, dtype: float64

# %%
A_LAP5.AccelerometerZ #reemplazar con lista
# Out:
# 0        -0.877741
# 1        -0.855396
# 2        -0.836786
# 3        -0.820175
# 4        -0.804771
#            ...
# 1765    -1.108.014
# 1766    -1.074.005
# 1767    -1.031.204
# 1768     -0.980282
# 1769     -0.937262
# Name: AccelerometerZ, Length: 1770, dtype: object

# %%
#creamos una lista para limpiar y luego incluir valores

lst2=[]

for x in A_LAP5.AccelerometerZ:
    
    lst2.append(float('.'.join(x.split('.')[:2])))
lst2[:10]
# Out:
# [-0.877741,
#  -0.855396,
#  -0.836786,
#  -0.820175,
#  -0.804771,
#  -0.789387,
#  -0.77375,
#  -0.7586,
#  -0.744655,
#  -0.730277]

# %%
A_LAP5['AccelerometerZ']=lst2

# %%
A_LAP5.AccelerometerZ #ya es float
# Out:
# 0      -0.877741
# 1      -0.855396
# 2      -0.836786
# 3      -0.820175
# 4      -0.804771
#           ...
# 1765   -1.108000
# 1766   -1.074000
# 1767   -1.031000
# 1768   -0.980282
# 1769   -0.937262
# Name: AccelerometerZ, Length: 1770, dtype: float64

# %%
A_LAP5.columns
# Out:
# Index(['Time', 'Distance', 'Logger_Temperature', 'AccelerometerX',
#        'AccelerometerY', 'AccelerometerZ', 'GyroX', 'GyroY', 'GyroZ',
#        'Int_Batt_Voltage', 'RPM', 'Calculated_Gear', 'GPS_Speed', 'GPS_Nsat',
#        'GPS_LatAcc', 'GPS_LonAcc', 'GPS_Slope', 'GPS_Heading', 'GPS_Gyro',
#        'GPS_Altitude', 'GPS_PosAccuracy', 'GPS_SpdAccuracy', 'GPS_Latitude',
#        'GPS_Longitude', 'GPS_Elevation'],
#       dtype='object')

# %%
A_LAP5.GyroX
# Out:
# 0       -0.591255
# 1       -0.500037
# 2       -0.444293
# 3       -0.418955
# 4       -0.429090
#           ...
# 1765    -0.479091
# 1766    -0.607809
# 1767    -0.704771
# 1768    -0.767610
# 1769    -0.801090
# Name: GyroX, Length: 1770, dtype: object

# %%
lst3=[]

for x in A_LAP5.GyroX:
    
    lst3.append(float('.'.join(x.split('.')[:2])))
lst3[:10]
# Out:
# [-0.591255,
#  -0.500037,
#  -0.444293,
#  -0.418955,
#  -0.42909,
#  -0.442604,
#  -0.401049,
#  -0.264898,
#  -0.00442,
#  0.339844]

# %%
A_LAP5['GyroX']=lst3

# %%
lst4=[]

for x in A_LAP5.GyroY:
    
    lst4.append(float('.'.join(x.split('.')[:2])))
lst4[:10]
# Out:
# [-2.063,
#  -1.943,
#  -1.733,
#  -1.51,
#  -1.352,
#  -1.248,
#  -1.166,
#  -1.095,
#  -1.031,
#  -0.973206]

# %%
A_LAP5['GyroY']=lst4

# %%
lst5=[]

for x in A_LAP5.GyroZ:
    
    lst5.append(float('.'.join(x.split('.')[:2])))



lst6=[]

for x in A_LAP5.Int_Batt_Voltage:
    
    lst6.append(float('.'.join(x.split('.')[:2])))
    
lst7=[]

for x in A_LAP5.RPM:
    
    lst7.append(float('.'.join(x.split('.')[:2])))
    

    
lst8=[]

for x in A_LAP5.Calculated_Gear:
    
    lst8.append(float('.'.join(x.split('.')[:2])))

    
    
lst9=[]

for x in A_LAP5.GPS_Speed:
    
    lst9.append(float('.'.join(x.split('.')[:2])))
    

lst10=[]

for x in A_LAP5.GPS_Nsat:
    
    lst10.append(float('.'.join(x.split('.')[:2])))

lst11=[]

for x in A_LAP5.GPS_LatAcc:
    
    lst11.append(float('.'.join(x.split('.')[:2])))
    
lst12=[]

for x in A_LAP5.GPS_LonAcc:
    
    lst12.append(float('.'.join(x.split('.')[:2])))
    
    
    
lst13=[]

for x in A_LAP5.GPS_Slope:
    
    lst13.append(float('.'.join(x.split('.')[:2])))
    
    
    
    
lst14=[]

for x in A_LAP5.GPS_Heading:
    
    lst14.append(float('.'.join(x.split('.')[:2])))
    
    
    
lst15=[]

for x in A_LAP5.GPS_Gyro:
    
    lst15.append(float('.'.join(x.split('.')[:2])))
    
 
  
    
lst16=[]

for x in A_LAP5.GPS_PosAccuracy:
    
    lst16.append(float('.'.join(x.split('.')[:2])))  
    

#CAMBIAMOS DATOS DE LOGITU, LATITUD ETC
lst17=[]

for x in A_LAP5.GPS_Altitude:
    
    lst17.append(float('.'.join(x.split('.')[:2])))  
    
lst18=[]

for x in A_LAP5.GPS_Latitude:
    
    lst18.append(float('.'.join(x.split('.')[:2])))  

    
    
lst19=[]

for x in A_LAP5.GPS_Longitude:
    
    lst19.append(float('.'.join(x.split('.')[:2])))  
    
    
lst20=[]

for x in A_LAP5.GPS_Heading:
    
    lst20.append(float('.'.join(x.split('.')[:2])))

# %%
A_LAP5['GyroZ']=lst5
A_LAP5['Int_Batt_Voltage']=lst6
A_LAP5['RPM']=lst7
A_LAP5['Calculated_Gear']=lst8
A_LAP5['GPS_Speed']=lst9
A_LAP5['GPS_Nsat']=lst10
A_LAP5['GPS_LatAcc']=lst11
A_LAP5['GPS_LonAcc']=lst12
A_LAP5['GPS_Slope']=lst13
A_LAP5['GPS_Gyro']=lst14
A_LAP5['GPS_PosAccuracy']=lst15
A_LAP5['GPS_SpdAccuracy']=lst16
A_LAP5['GPS_Altitude']=lst17
A_LAP5['GPS_Latitude']=lst18
A_LAP5['GPS_Longitude']=lst19
A_LAP5['GPS_Heading']=lst20

# %%
A_LAP5.columns
# Out:
# Index(['Time', 'Distance', 'Logger_Temperature', 'AccelerometerX',
#        'AccelerometerY', 'AccelerometerZ', 'GyroX', 'GyroY', 'GyroZ',
#        'Int_Batt_Voltage', 'RPM', 'Calculated_Gear', 'GPS_Speed', 'GPS_Nsat',
#        'GPS_LatAcc', 'GPS_LonAcc', 'GPS_Slope', 'GPS_Heading', 'GPS_Gyro',
#        'GPS_Altitude', 'GPS_PosAccuracy', 'GPS_SpdAccuracy', 'GPS_Latitude',
#        'GPS_Longitude', 'GPS_Elevation'],
#       dtype='object')

# %%
A_LAP5.info() #ya son float todos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1770 entries, 0 to 1769
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time                1770 non-null   float64
#  1   Distance            1770 non-null   float64
#  2   Logger_Temperature  1770 non-null   float64
#  3   AccelerometerX      1770 non-null   float64
#  4   AccelerometerY      1770 non-null   float64
#  5   AccelerometerZ      1770 non-null   float64
#  6   GyroX               1770 non-null   float64
#  7   GyroY               1770 non-null   float64
#  8   GyroZ               1770 non-null   float64
#  9   Int_Batt_Voltage    1770 non-null   float64
#  10  RPM                 1770 non-null   float64
#  11  Calculated_Gear     1770 non-null   float64
#  12  GPS_Speed           1770 non-null   float64
#  13  GPS_Nsat            1770 non-null   float64
#  14  GPS_LatAcc          1770 non-null   float64
# ...

# %%
A_LAP5
# Out:
#         Time  Distance  Logger_Temperature  AccelerometerX  AccelerometerY  \
# 0      0.000     0.000              31.857       -0.354309       -0.119869
# 1      0.050     0.001              31.858       -0.412061       -0.128056
# 2      0.100     0.002              31.860       -0.454671       -0.130070
# 3      0.150     0.003              31.862       -0.489577       -0.129646
# 4      0.200     0.004              31.864       -0.522539       -0.122892
# ...      ...       ...                 ...             ...             ...
# 1765  88.250     1.378              31.332        0.344260       -0.041210
# 1766  88.300     1.379              31.335        0.241562       -0.048349
# 1767  88.350     1.380              31.338        0.118076       -0.057280
# 1768  88.400     1.381              31.341       -0.022231       -0.072207
# 1769  88.441     1.382              31.343       -0.143418       -0.086218
#
# ...

# %% [markdown]
# # LIMPIEZA VUELTA RÁPIDA D

# %%
#La vuelta rápida del piloto D es LAP8

# %%
D_LAP8.head()
# Out:
#    Time  Distance Logger Temperature AccelerometerX AccelerometerY  \
# 0  0.00     0.000         29.033.611      -0.127022      -0.080426
# 1  0.05     0.001         29.037.485      -0.323807      -0.098249
# 2  0.10     0.002         29.041.357      -0.509733      -0.116959
# 3  0.15     0.003         29.045.229      -0.669747      -0.133199
# 4  0.20     0.004         29.049.103      -0.792629      -0.147358
#
#   AccelerometerZ      GyroX       GyroY       GyroZ Int Batt Voltage  \
# 0      -0.943003  -0.675442  -3.577.503  -1.664.530        3.777.259
# 1      -0.872662  -0.726767  -4.111.012  -2.250.630        3.777.847
# 2      -0.805965  -0.781491  -4.221.333  -2.821.643        3.778.435
# 3      -0.748346  -0.827250  -3.947.670  -3.330.658        3.779.023
# 4      -0.701764  -0.838238  -3.369.381  -3.721.047        3.779.612
#
#              RPM Calculated_Gear   GPS_Speed    GPS_Nsat GPS_LatAcc  \
# 0  8.520.005.859       2.999.985  76.714.005  12.000.000  -0.102520
# ...

# %%
len(A_LAP5.columns) == len(D_LAP8.columns)
# Out:
# True

# %%
D_LAP8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1698 entries, 0 to 1697
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time                1698 non-null   float64
#  1   Distance            1698 non-null   float64
#  2   Logger Temperature  1698 non-null   object
#  3   AccelerometerX      1698 non-null   object
#  4   AccelerometerY      1698 non-null   object
#  5   AccelerometerZ      1698 non-null   object
#  6   GyroX               1698 non-null   object
#  7   GyroY               1698 non-null   object
#  8   GyroZ               1698 non-null   object
#  9   Int Batt Voltage    1698 non-null   object
#  10  RPM                 1698 non-null   object
#  11  Calculated_Gear     1698 non-null   object
#  12  GPS_Speed           1698 non-null   object
#  13  GPS_Nsat            1698 non-null   object
#  14  GPS_LatAcc          1698 non-null   object
# ...

# %%
D_LAP8.columns
# Out:
# Index(['Time', 'Distance', 'Logger Temperature', 'AccelerometerX',
#        'AccelerometerY', 'AccelerometerZ', 'GyroX', 'GyroY', 'GyroZ',
#        'Int Batt Voltage', 'RPM', 'Calculated_Gear', 'GPS_Speed', 'GPS_Nsat',
#        'GPS_LatAcc', 'GPS_LonAcc', 'GPS_Slope', 'GPS_Heading', 'GPS_Gyro',
#        'GPS_Altitude', 'GPS_PosAccuracy', 'GPS_SpdAccuracy', 'GPS_Latitude',
#        'GPS_Longitude', 'GPS_Elevation'],
#       dtype='object')

# %%
#renombramos las columnas
D_LAP8.rename(columns={'Logger Temperature':'Logger_Temperature',
                        'Int Batt Voltage':'Int_Batt_Voltage'},
               inplace=True)
D_LAP8.columns
# Out:
# Index(['Time', 'Distance', 'Logger_Temperature', 'AccelerometerX',
#        'AccelerometerY', 'AccelerometerZ', 'GyroX', 'GyroY', 'GyroZ',
#        'Int_Batt_Voltage', 'RPM', 'Calculated_Gear', 'GPS_Speed', 'GPS_Nsat',
#        'GPS_LatAcc', 'GPS_LonAcc', 'GPS_Slope', 'GPS_Heading', 'GPS_Gyro',
#        'GPS_Altitude', 'GPS_PosAccuracy', 'GPS_SpdAccuracy', 'GPS_Latitude',
#        'GPS_Longitude', 'GPS_Elevation'],
#       dtype='object')

# %%
D_LAP8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1698 entries, 0 to 1697
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time                1698 non-null   float64
#  1   Distance            1698 non-null   float64
#  2   Logger_Temperature  1698 non-null   object
#  3   AccelerometerX      1698 non-null   object
#  4   AccelerometerY      1698 non-null   object
#  5   AccelerometerZ      1698 non-null   object
#  6   GyroX               1698 non-null   object
#  7   GyroY               1698 non-null   object
#  8   GyroZ               1698 non-null   object
#  9   Int_Batt_Voltage    1698 non-null   object
#  10  RPM                 1698 non-null   object
#  11  Calculated_Gear     1698 non-null   object
#  12  GPS_Speed           1698 non-null   object
#  13  GPS_Nsat            1698 non-null   object
#  14  GPS_LatAcc          1698 non-null   object
# ...

# %%
#pasamos a numeros todos los object
lst=[]

for x in D_LAP8.Logger_Temperature:
    
    lst.append(float('.'.join(x.split('.')[:2])))


lst1=[]

for x in D_LAP8.AccelerometerX:
    
    lst1.append(float('.'.join(x.split('.')[:2])))
    
lst2=[]

for x in D_LAP8.AccelerometerY:
    
    lst2.append(float('.'.join(x.split('.')[:2])))
    
lst3=[]

for x in D_LAP8.AccelerometerZ:
    
    lst3.append(float('.'.join(x.split('.')[:2])))   
    
lst4=[]

for x in D_LAP8.GyroX:
    
    lst4.append(float('.'.join(x.split('.')[:2]))) 

lst5=[]

for x in D_LAP8.GyroY:
    
    lst5.append(float('.'.join(x.split('.')[:2])))

lst6=[]

for x in D_LAP8.GyroZ:
    
    lst6.append(float('.'.join(x.split('.')[:2])))
    
lst7=[]

for x in D_LAP8.Int_Batt_Voltage:
    
    lst7.append(float('.'.join(x.split('.')[:2])))    
    
lst8=[]

for x in D_LAP8.RPM:
    
    lst8.append(float('.'.join(x.split('.')[:2])))
       
    
lst9=[]

for x in D_LAP8.Calculated_Gear:
    
    lst9.append(float('.'.join(x.split('.')[:2])))
    
    
    
lst10=[]

for x in D_LAP8.GPS_Speed:
    
    lst10.append(float('.'.join(x.split('.')[:2])))
    
 
  
    
lst11=[]

for x in D_LAP8.GPS_Nsat:
    
    lst11.append(float('.'.join(x.split('.')[:2])))  
    

lst12=[]

for x in D_LAP8.GPS_LatAcc:
    
    lst12.append(float('.'.join(x.split('.')[:2])))  
    
lst13=[]

for x in D_LAP8.GPS_LonAcc:
    
    lst13.append(float('.'.join(x.split('.')[:2])))  

    
    
lst14=[]

for x in D_LAP8.GPS_Slope:
    
    lst14.append(float('.'.join(x.split('.')[:2])))  
    
    
lst15=[]

for x in D_LAP8.GPS_Heading:
    
    lst15.append(float('.'.join(x.split('.')[:2])))  
    
    
lst16=[]

for x in D_LAP8.GPS_Gyro:
    
    lst16.append(float('.'.join(x.split('.')[:2])))
    
    
lst17=[]

for x in D_LAP8.GPS_Altitude:
    
    lst17.append(float('.'.join(x.split('.')[:2])))
    
    
lst18=[]

for x in D_LAP8.GPS_PosAccuracy:
    
    lst18.append(float('.'.join(x.split('.')[:2])))

    
    
lst19=[]

for x in D_LAP8.GPS_Latitude:
    
    lst19.append(float('.'.join(x.split('.')[:2])))


lst20=[]

for x in D_LAP8.GPS_Longitude:
    
    lst20.append(float('.'.join(x.split('.')[:2])))

# %%
D_LAP8['Logger_Temperature']=lst
D_LAP8['AccelerometerX']=lst1
D_LAP8['AccelerometerY']=lst2
D_LAP8['AccelerometerZ']=lst3
D_LAP8['GyroX']=lst4
D_LAP8['GyroY']=lst5
D_LAP8['GyroZ']=lst6
D_LAP8['Int_Batt_Voltage']=lst7
D_LAP8['RPM']=lst8
D_LAP8['Calculated_Gear']=lst9
D_LAP8['GPS_Speed']=lst10
D_LAP8['GPS_Nsat']=lst11
D_LAP8['GPS_LatAcc']=lst12
D_LAP8['GPS_LonAcc']=lst13
D_LAP8['GPS_Slope']=lst14
D_LAP8['GPS_Heading']=lst15
D_LAP8['GPS_Gyro']=lst16
D_LAP8['GPS_Altitude']=lst17
D_LAP8['GPS_PosAccuracy']=lst18
D_LAP8['GPS_Latitude']=lst19
D_LAP8['GPS_Longitude']=lst20

# %%
D_LAP8.info() #ya son todos floats
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1698 entries, 0 to 1697
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time                1698 non-null   float64
#  1   Distance            1698 non-null   float64
#  2   Logger_Temperature  1698 non-null   float64
#  3   AccelerometerX      1698 non-null   float64
#  4   AccelerometerY      1698 non-null   float64
#  5   AccelerometerZ      1698 non-null   float64
#  6   GyroX               1698 non-null   float64
#  7   GyroY               1698 non-null   float64
#  8   GyroZ               1698 non-null   float64
#  9   Int_Batt_Voltage    1698 non-null   float64
#  10  RPM                 1698 non-null   float64
#  11  Calculated_Gear     1698 non-null   float64
#  12  GPS_Speed           1698 non-null   float64
#  13  GPS_Nsat            1698 non-null   float64
#  14  GPS_LatAcc          1698 non-null   float64
# ...

# %% [markdown]
# # LIMPIAMOS EL RESTO DE DATAFRAMES

# %%
#empezamos con Race de A
A_RACE.info() #todo float lo podemos dejar así
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14822 entries, 0 to 14821
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time                14822 non-null  float64
#  1   Distance            14822 non-null  float64
#  2   Logger Temperature  14822 non-null  float64
#  3   AccelerometerX      14822 non-null  float64
#  4   AccelerometerY      14822 non-null  float64
#  5   AccelerometerZ      14822 non-null  float64
#  6   GyroX               14822 non-null  float64
#  7   GyroY               14822 non-null  float64
#  8   GyroZ               14822 non-null  float64
#  9   Int Batt Voltage    14822 non-null  float64
#  10  RPM                 14822 non-null  float64
#  11  Calculated_Gear     14822 non-null  float64
#  12  GPS_Speed           14822 non-null  float64
#  13  GPS_Nsat            14822 non-null  float64
#  14  GPS_LatAcc          14822 non-null  float64
# ...

# %%
A_RACE.head() #hay que reemplazar el nombre de las columnas
# Out:
#    Time  Distance  Logger Temperature  AccelerometerX  AccelerometerY  \
# 0  0.00     0.000           33.687458        0.336049       -0.030920
# 1  0.05     0.001           33.687458        0.280212       -0.037097
# 2  0.10     0.001           33.687458        0.217850       -0.046059
# 3  0.15     0.002           33.687458        0.153605       -0.055294
# 4  0.20     0.003           33.687458        0.078337       -0.067040
#
#    AccelerometerZ     GyroX     GyroY     GyroZ  Int Batt Voltage  \
# 0       -1.106257  0.126529 -0.397233 -0.057876          3.829999
# 1       -1.084871  0.029263 -0.612686 -0.209471          3.829999
# 2       -1.062477 -0.122091 -0.709052 -0.514913          3.830011
# 3       -1.038093 -0.272904 -0.747262 -0.929335          3.830074
# 4       -1.010092 -0.422874 -0.846158 -1.397355          3.830161
#
#            RPM  Calculated_Gear  GPS_Speed  GPS_Nsat  GPS_LatAcc  GPS_LonAcc  \
# ...

# %%
D_RACE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39137 entries, 0 to 39136
# Data columns (total 30 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time                39137 non-null  float64
#  1   Distance            39137 non-null  float64
#  2   Logger Temperature  39137 non-null  object
#  3   AccelerometerX      39137 non-null  object
#  4   AccelerometerY      39137 non-null  object
#  5   AccelerometerZ      39137 non-null  object
#  6   GyroX               39137 non-null  object
#  7   GyroY               39137 non-null  object
#  8   GyroZ               39137 non-null  object
#  9   Int Batt Voltage    39137 non-null  object
#  10  RPM                 39137 non-null  object
#  11  Calculated_Gear     39137 non-null  object
#  12  GPS_Speed           39137 non-null  object
#  13  GPS_Nsat            39137 non-null  object
#  14  GPS_LatAcc          39137 non-null  object
# ...

# %%
#D_RACE['AccelerometerX'] = D_RACE['AccelerometerX'].astype(float) PARA INTENTAR PASARLO FACILMENTE
