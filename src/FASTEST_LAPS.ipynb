# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.collections import LineCollection
from matplotlib import cm

import warnings
warnings.filterwarnings('ignore')  

pd.set_option('display.max_columns', None)

# %% [markdown]
# # FASTEST LAP DRIVER A

# %%
ALB_LAP5 = pd.read_csv('../../../Desktop/MA22RT_PROJECT/laps_database/DIVISION_copia/FSS_ENDURANCE_ALBA_LAP_5.csv', encoding='latin1', sep=';')

# %%
ALB_LAP5.head()
# Out:
#    Time  Distance Logger Temperature  AccelerometerX AccelerometerY  \
# 0  0.00     0.000         31.857.067       -0.354309      -0.119869
# 1  0.05     0.001         31.858.870       -0.412061      -0.128056
# 2  0.10     0.002         31.860.674       -0.454671      -0.130070
# 3  0.15     0.003         31.862.476       -0.489577      -0.129646
# 4  0.20     0.004         31.864.281       -0.522539      -0.122892
#
#   AccelerometerZ      GyroX       GyroY       GyroZ Int Batt Voltage  \
# 0      -0.877741  -0.591255  -2.063.972  -2.258.865        3.815.367
# 1      -0.855396  -0.500037  -1.943.496  -2.134.022        3.815.464
# 2      -0.836786  -0.444293  -1.733.240  -1.902.171        3.815.562
# 3      -0.820175  -0.418955  -1.510.336  -1.623.387        3.815.659
# 4      -0.804771  -0.429090  -1.352.375  -1.333.338        3.815.756
#
#              RPM Calculated_Gear   GPS_Speed    GPS_Nsat GPS_LatAcc  \
# 0  9.161.995.117       4.000.000  70.110.001  15.000.000  -0.094833
# ...

# %%
ALB_LAP5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1770 entries, 0 to 1769
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time                1770 non-null   float64
#  1   Distance            1770 non-null   float64
#  2   Logger Temperature  1770 non-null   object
#  3   AccelerometerX      1770 non-null   float64
#  4   AccelerometerY      1770 non-null   object
#  5   AccelerometerZ      1770 non-null   object
#  6   GyroX               1770 non-null   object
#  7   GyroY               1770 non-null   object
#  8   GyroZ               1770 non-null   object
#  9   Int Batt Voltage    1770 non-null   object
#  10  RPM                 1770 non-null   object
#  11  Calculated_Gear     1770 non-null   object
#  12  GPS_Speed           1770 non-null   object
#  13  GPS_Nsat            1770 non-null   object
#  14  GPS_LatAcc          1770 non-null   object
# ...

# %%
ALB_LAP5.rename(columns={'Logger Temperature':'Logger_Temperature',
                        'Int Batt Voltage':'Int_Batt_Voltage'},
               inplace=True)
ALB_LAP5.columns
# Out:
# Index(['Time', 'Distance', 'Logger_Temperature', 'AccelerometerX',
#        'AccelerometerY', 'AccelerometerZ', 'GyroX', 'GyroY', 'GyroZ',
#        'Int_Batt_Voltage', 'RPM', 'Calculated_Gear', 'GPS_Speed', 'GPS_Nsat',
#        'GPS_LatAcc', 'GPS_LonAcc', 'GPS_Slope', 'GPS_Heading', 'GPS_Gyro',
#        'GPS_Altitude', 'GPS_PosAccuracy', 'GPS_SpdAccuracy', 'GPS_Latitude',
#        'GPS_Longitude', 'GPS_Elevation'],
#       dtype='object')

# %%
lst=[]

for x in ALB_LAP5.Logger_Temperature:
    
    lst.append(float('.'.join(x.split('.')[:2])))

    
lst1=[]

for x in ALB_LAP5.AccelerometerY:
    
    lst1.append(float('.'.join(x.split('.')[:2])))

    
lst2=[]

for x in ALB_LAP5.AccelerometerZ:
    
    lst2.append(float('.'.join(x.split('.')[:2])))

lst3=[]

for x in ALB_LAP5.GyroX:
    
    lst3.append(float('.'.join(x.split('.')[:2])))

lst4=[]

for x in ALB_LAP5.GyroY:
    
    lst4.append(float('.'.join(x.split('.')[:2])))
    
lst5=[]

for x in ALB_LAP5.GyroZ:
    
    lst5.append(float('.'.join(x.split('.')[:2])))



lst6=[]

for x in ALB_LAP5.Int_Batt_Voltage:
    
    lst6.append(float('.'.join(x.split('.')[:2])))
    
lst7=[]

for x in ALB_LAP5.RPM:
    
    lst7.append(float('.'.join(x.split('.')[:2])))
    

    
lst8=[]

for x in ALB_LAP5.Calculated_Gear:
    
    lst8.append(float('.'.join(x.split('.')[:2])))

    
    
lst9=[]

for x in ALB_LAP5.GPS_Speed:
    
    lst9.append(float('.'.join(x.split('.')[:2])))
    

lst10=[]

for x in ALB_LAP5.GPS_Nsat:
    
    lst10.append(float('.'.join(x.split('.')[:2])))

lst11=[]

for x in ALB_LAP5.GPS_LatAcc:
    
    lst11.append(float('.'.join(x.split('.')[:2])))
    
lst12=[]

for x in ALB_LAP5.GPS_LonAcc:
    
    lst12.append(float('.'.join(x.split('.')[:2])))
    
    
    
lst13=[]

for x in ALB_LAP5.GPS_Slope:
    
    lst13.append(float('.'.join(x.split('.')[:2])))
    
    
    
    
lst14=[]

for x in ALB_LAP5.GPS_Heading:
    
    lst14.append(float('.'.join(x.split('.')[:2])))
    
    
    
lst15=[]

for x in ALB_LAP5.GPS_Gyro:
    
    lst15.append(float('.'.join(x.split('.')[:2])))
    
 
  
    
lst16=[]

for x in ALB_LAP5.GPS_PosAccuracy:
    
    lst16.append(float('.'.join(x.split('.')[:2])))  
    

lst17=[]

for x in ALB_LAP5.GPS_Altitude:
    
    lst17.append(float('.'.join(x.split('.')[:2])))  

    


    
#ALB_LAP5.GPS_Latitude.apply(lambda x: float(x.replace('.', '')[:2]+'.'+x.replace('.', '')[2:])).values
    




#ALB_LAP5.GPS_Longitude.apply(lambda x: float(x.replace('.', '')[0]+'.'+x.replace('.', '')[1:])).values
    
    
lst18=[]

for x in ALB_LAP5.GPS_Heading:
    
    lst18.append(float('.'.join(x.split('.')[:2])))

# %%
ALB_LAP5['AccelerometerY']=lst1
ALB_LAP5['AccelerometerZ']=lst2
ALB_LAP5['GyroX']=lst3
ALB_LAP5['GyroY']=lst4
ALB_LAP5['GyroZ']=lst5
ALB_LAP5['Int_Batt_Voltage']=lst6
ALB_LAP5['RPM']=lst7
ALB_LAP5['Calculated_Gear']=lst8
ALB_LAP5['GPS_Speed']=lst9
ALB_LAP5['GPS_Nsat']=lst10
ALB_LAP5['GPS_LatAcc']=lst11
ALB_LAP5['GPS_LonAcc']=lst12
ALB_LAP5['GPS_Slope']=lst13
ALB_LAP5['GPS_Gyro']=lst14
ALB_LAP5['GPS_PosAccuracy']=lst15
ALB_LAP5['GPS_SpdAccuracy']=lst16
ALB_LAP5['GPS_Altitude']=lst17
ALB_LAP5['GPS_Heading']=lst18

# %%
ALB_LAP5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1770 entries, 0 to 1769
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time                1770 non-null   float64
#  1   Distance            1770 non-null   float64
#  2   Logger_Temperature  1770 non-null   object
#  3   AccelerometerX      1770 non-null   float64
#  4   AccelerometerY      1770 non-null   float64
#  5   AccelerometerZ      1770 non-null   float64
#  6   GyroX               1770 non-null   float64
#  7   GyroY               1770 non-null   float64
#  8   GyroZ               1770 non-null   float64
#  9   Int_Batt_Voltage    1770 non-null   float64
#  10  RPM                 1770 non-null   float64
#  11  Calculated_Gear     1770 non-null   float64
#  12  GPS_Speed           1770 non-null   float64
#  13  GPS_Nsat            1770 non-null   float64
#  14  GPS_LatAcc          1770 non-null   float64
# ...

# %%
lst20=[]
GPS_Latitude=ALB_LAP5.GPS_Latitude.apply(lambda x: float(x.replace('.', '')[:2]+'.'+x.replace('.', '')[2:])).values
for i in GPS_Latitude:
    lst20.append(i)
lst20[:20]
# Out:
# [41.592248264145,
#  41.592249539817,
#  41.592250812616,
#  41.592252071976,
#  41.592253299309,
#  41.5922544795,
#  41.592255596143,
#  41.592256640615,
#  41.592257607527,
#  41.59225849713,
#  41.592259310131,
#  41.592260048232,
#  41.592260705971,
#  41.592261279961,
#  41.592261761322,
#  41.592262140648,
#  41.592262399894,
#  41.592262521869,
#  41.592262483924,
#  41.592262266857]

# %%
ALB_LAP5['GPS_Latitude']=lst20

# %%
ALB_LAP5.head()
# Out:
#    Time  Distance Logger_Temperature  AccelerometerX  AccelerometerY  \
# 0  0.00     0.000         31.857.067       -0.354309       -0.119869
# 1  0.05     0.001         31.858.870       -0.412061       -0.128056
# 2  0.10     0.002         31.860.674       -0.454671       -0.130070
# 3  0.15     0.003         31.862.476       -0.489577       -0.129646
# 4  0.20     0.004         31.864.281       -0.522539       -0.122892
#
#    AccelerometerZ     GyroX  GyroY  GyroZ  Int_Batt_Voltage    RPM  \
# 0       -0.877741 -0.591255 -2.063 -2.258             3.815  9.161
# 1       -0.855396 -0.500037 -1.943 -2.134             3.815  8.947
# 2       -0.836786 -0.444293 -1.733 -1.902             3.815  8.712
# 3       -0.820175 -0.418955 -1.510 -1.623             3.815  8.413
# 4       -0.804771 -0.429090 -1.352 -1.333             3.815  8.163
#
#    Calculated_Gear  GPS_Speed  GPS_Nsat  GPS_LatAcc  GPS_LonAcc  GPS_Slope  \
# ...

# %%
lst21=[]
GPS_Longitude=ALB_LAP5.GPS_Longitude.apply(lambda x: float(x.replace('.', '')[0]+'.'+x.replace('.', '')[1:])).values
for i in GPS_Longitude:
    lst21.append(i)
lst21[:10]
# Out:
# [1.688812108174,
#  1.688823234507,
#  1.688834194129,
#  1.688844976103,
#  1.688855555753,
#  1.688865913964,
#  1.688876028042,
#  1.688885889813,
#  1.688895501985,
#  1.688904872173]

# %%
ALB_LAP5['GPS_Longitude']=lst21

# %%
ALB_LAP5.head()
# Out:
#    Time  Distance Logger_Temperature  AccelerometerX  AccelerometerY  \
# 0  0.00     0.000         31.857.067       -0.354309       -0.119869
# 1  0.05     0.001         31.858.870       -0.412061       -0.128056
# 2  0.10     0.002         31.860.674       -0.454671       -0.130070
# 3  0.15     0.003         31.862.476       -0.489577       -0.129646
# 4  0.20     0.004         31.864.281       -0.522539       -0.122892
#
#    AccelerometerZ     GyroX  GyroY  GyroZ  Int_Batt_Voltage    RPM  \
# 0       -0.877741 -0.591255 -2.063 -2.258             3.815  9.161
# 1       -0.855396 -0.500037 -1.943 -2.134             3.815  8.947
# 2       -0.836786 -0.444293 -1.733 -1.902             3.815  8.712
# 3       -0.820175 -0.418955 -1.510 -1.623             3.815  8.413
# 4       -0.804771 -0.429090 -1.352 -1.333             3.815  8.163
#
#    Calculated_Gear  GPS_Speed  GPS_Nsat  GPS_LatAcc  GPS_LonAcc  GPS_Slope  \
# ...

# %%
ALB_LAP5.head()
# Out:
#    Time  Distance Logger_Temperature  AccelerometerX  AccelerometerY  \
# 0  0.00     0.000         31.857.067       -0.354309       -0.119869
# 1  0.05     0.001         31.858.870       -0.412061       -0.128056
# 2  0.10     0.002         31.860.674       -0.454671       -0.130070
# 3  0.15     0.003         31.862.476       -0.489577       -0.129646
# 4  0.20     0.004         31.864.281       -0.522539       -0.122892
#
#    AccelerometerZ     GyroX  GyroY  GyroZ  Int_Batt_Voltage    RPM  \
# 0       -0.877741 -0.591255 -2.063 -2.258             3.815  9.161
# 1       -0.855396 -0.500037 -1.943 -2.134             3.815  8.947
# 2       -0.836786 -0.444293 -1.733 -1.902             3.815  8.712
# 3       -0.820175 -0.418955 -1.510 -1.623             3.815  8.413
# 4       -0.804771 -0.429090 -1.352 -1.333             3.815  8.163
#
#    Calculated_Gear  GPS_Speed  GPS_Nsat  GPS_LatAcc  GPS_LonAcc  GPS_Slope  \
# ...

# %%
ALB_LAP5.to_csv('../../../Desktop/ALB_LAP5.csv')

# %%
ALB_LAP5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1770 entries, 0 to 1769
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time                1770 non-null   float64
#  1   Distance            1770 non-null   float64
#  2   Logger_Temperature  1770 non-null   object
#  3   AccelerometerX      1770 non-null   float64
#  4   AccelerometerY      1770 non-null   float64
#  5   AccelerometerZ      1770 non-null   float64
#  6   GyroX               1770 non-null   float64
#  7   GyroY               1770 non-null   float64
#  8   GyroZ               1770 non-null   float64
#  9   Int_Batt_Voltage    1770 non-null   float64
#  10  RPM                 1770 non-null   float64
#  11  Calculated_Gear     1770 non-null   float64
#  12  GPS_Speed           1770 non-null   float64
#  13  GPS_Nsat            1770 non-null   float64
#  14  GPS_LatAcc          1770 non-null   float64
# ...

# %% [markdown]
# # FASTEST LAP DRIVER D

# %%
DAV_LAP8 = pd.read_csv('../../../Desktop/MA22RT_PROJECT/laps_database/DIVISION_copia/FSS_ENDURANCE_DAVID_LAP_8.csv', encoding='latin1', sep=';')

# %%
DAV_LAP8.head()
# Out:
#    Time  Distance Logger Temperature AccelerometerX AccelerometerY  \
# 0  0.00     0.000         29.033.611      -0.127022      -0.080426
# 1  0.05     0.001         29.037.485      -0.323807      -0.098249
# 2  0.10     0.002         29.041.357      -0.509733      -0.116959
# 3  0.15     0.003         29.045.229      -0.669747      -0.133199
# 4  0.20     0.004         29.049.103      -0.792629      -0.147358
#
#   AccelerometerZ      GyroX       GyroY       GyroZ Int Batt Voltage  \
# 0      -0.943003  -0.675442  -3.577.503  -1.664.530        3.777.259
# 1      -0.872662  -0.726767  -4.111.012  -2.250.630        3.777.847
# 2      -0.805965  -0.781491  -4.221.333  -2.821.643        3.778.435
# 3      -0.748346  -0.827250  -3.947.670  -3.330.658        3.779.023
# 4      -0.701764  -0.838238  -3.369.381  -3.721.047        3.779.612
#
#              RPM Calculated_Gear   GPS_Speed    GPS_Nsat GPS_LatAcc  \
# 0  8.520.005.859       2.999.985  76.714.005  12.000.000  -0.102520
# ...

# %%
DAV_LAP8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1698 entries, 0 to 1697
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time                1698 non-null   float64
#  1   Distance            1698 non-null   float64
#  2   Logger Temperature  1698 non-null   object
#  3   AccelerometerX      1698 non-null   object
#  4   AccelerometerY      1698 non-null   object
#  5   AccelerometerZ      1698 non-null   object
#  6   GyroX               1698 non-null   object
#  7   GyroY               1698 non-null   object
#  8   GyroZ               1698 non-null   object
#  9   Int Batt Voltage    1698 non-null   object
#  10  RPM                 1698 non-null   object
#  11  Calculated_Gear     1698 non-null   object
#  12  GPS_Speed           1698 non-null   object
#  13  GPS_Nsat            1698 non-null   object
#  14  GPS_LatAcc          1698 non-null   object
# ...

# %%
DAV_LAP8.rename(columns={'Logger Temperature':'Logger_Temperature',
                        'Int Batt Voltage':'Int_Batt_Voltage'},
               inplace=True)
DAV_LAP8.columns
# Out:
# Index(['Time', 'Distance', 'Logger_Temperature', 'AccelerometerX',
#        'AccelerometerY', 'AccelerometerZ', 'GyroX', 'GyroY', 'GyroZ',
#        'Int_Batt_Voltage', 'RPM', 'Calculated_Gear', 'GPS_Speed', 'GPS_Nsat',
#        'GPS_LatAcc', 'GPS_LonAcc', 'GPS_Slope', 'GPS_Heading', 'GPS_Gyro',
#        'GPS_Altitude', 'GPS_PosAccuracy', 'GPS_SpdAccuracy', 'GPS_Latitude',
#        'GPS_Longitude', 'GPS_Elevation'],
#       dtype='object')

# %%
lst=[]

for x in DAV_LAP8.Logger_Temperature:
    
    lst.append(float('.'.join(x.split('.')[:2])))

    
lst1=[]

for x in DAV_LAP8.AccelerometerY:
    
    lst1.append(float('.'.join(x.split('.')[:2])))

    
lst2=[]

for x in DAV_LAP8.AccelerometerZ:
    
    lst2.append(float('.'.join(x.split('.')[:2])))

lst3=[]

for x in DAV_LAP8.GyroX:
    
    lst3.append(float('.'.join(x.split('.')[:2])))

lst4=[]

for x in DAV_LAP8.GyroY:
    
    lst4.append(float('.'.join(x.split('.')[:2])))
    
lst5=[]

for x in DAV_LAP8.GyroZ:
    
    lst5.append(float('.'.join(x.split('.')[:2])))



lst6=[]

for x in DAV_LAP8.Int_Batt_Voltage:
    
    lst6.append(float('.'.join(x.split('.')[:2])))
    
lst7=[]

for x in DAV_LAP8.RPM:
    
    lst7.append(float('.'.join(x.split('.')[:2])))
    

    
lst8=[]

for x in DAV_LAP8.Calculated_Gear:
    
    lst8.append(float('.'.join(x.split('.')[:2])))

    
    
lst9=[]

for x in DAV_LAP8.GPS_Speed:
    
    lst9.append(float('.'.join(x.split('.')[:2])))
    

lst10=[]

for x in DAV_LAP8.GPS_Nsat:
    
    lst10.append(float('.'.join(x.split('.')[:2])))

lst11=[]

for x in DAV_LAP8.GPS_LatAcc:
    
    lst11.append(float('.'.join(x.split('.')[:2])))
    
lst12=[]

for x in DAV_LAP8.GPS_LonAcc:
    
    lst12.append(float('.'.join(x.split('.')[:2])))
    
    
    
lst13=[]

for x in DAV_LAP8.GPS_Slope:
    
    lst13.append(float('.'.join(x.split('.')[:2])))
    
    
    
    
lst14=[]

for x in DAV_LAP8.GPS_Heading:
    
    lst14.append(float('.'.join(x.split('.')[:2])))
    
    
    
lst15=[]

for x in DAV_LAP8.GPS_Gyro:
    
    lst15.append(float('.'.join(x.split('.')[:2])))
    
 
  
    
lst16=[]

for x in DAV_LAP8.GPS_PosAccuracy:
    
    lst16.append(float('.'.join(x.split('.')[:2])))  
    

lst17=[]

for x in DAV_LAP8.GPS_Altitude:
    
    lst17.append(float('.'.join(x.split('.')[:2])))  

    
    
    
lst18=[]

for x in DAV_LAP8.GPS_Heading:
    
    lst18.append(float('.'.join(x.split('.')[:2])))

# %%
DAV_LAP8['AccelerometerY']=lst1
DAV_LAP8['AccelerometerZ']=lst2
DAV_LAP8['GyroX']=lst3
DAV_LAP8['GyroY']=lst4
DAV_LAP8['GyroZ']=lst5
DAV_LAP8['Int_Batt_Voltage']=lst6
DAV_LAP8['RPM']=lst7
DAV_LAP8['Calculated_Gear']=lst8
DAV_LAP8['GPS_Speed']=lst9
DAV_LAP8['GPS_Nsat']=lst10
DAV_LAP8['GPS_LatAcc']=lst11
DAV_LAP8['GPS_LonAcc']=lst12
DAV_LAP8['GPS_Slope']=lst13
DAV_LAP8['GPS_Gyro']=lst14
DAV_LAP8['GPS_PosAccuracy']=lst15
DAV_LAP8['GPS_SpdAccuracy']=lst16
DAV_LAP8['GPS_Altitude']=lst17
DAV_LAP8['GPS_Heading']=lst18

# %%
DAV_LAP8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1698 entries, 0 to 1697
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time                1698 non-null   float64
#  1   Distance            1698 non-null   float64
#  2   Logger_Temperature  1698 non-null   object
#  3   AccelerometerX      1698 non-null   object
#  4   AccelerometerY      1698 non-null   float64
#  5   AccelerometerZ      1698 non-null   float64
#  6   GyroX               1698 non-null   float64
#  7   GyroY               1698 non-null   float64
#  8   GyroZ               1698 non-null   float64
#  9   Int_Batt_Voltage    1698 non-null   float64
#  10  RPM                 1698 non-null   float64
#  11  Calculated_Gear     1698 non-null   float64
#  12  GPS_Speed           1698 non-null   float64
#  13  GPS_Nsat            1698 non-null   float64
#  14  GPS_LatAcc          1698 non-null   float64
# ...

# %%
lst20=[]
GPS_Latitude=DAV_LAP8.GPS_Latitude.apply(lambda x: float(x.replace('.', '')[:2]+'.'+x.replace('.', '')[2:])).values
for i in GPS_Latitude:
    lst20.append(i)
lst20[:20]
# Out:
# [41.592268295179,
#  41.592269489215,
#  41.592270663746,
#  41.592271822591,
#  41.5922729628,
#  41.592274088057,
#  41.592275195321,
#  41.592276284527,
#  41.592277345003,
#  41.592278366652,
#  41.592279329924,
#  41.592280206119,
#  41.592280948565,
#  41.592281517844,
#  41.592281868503,
#  41.592281970412,
#  41.592281794327,
#  41.592281332402,
#  41.592280588339,
#  41.592279567952]

# %%
DAV_LAP8['GPS_Latitude']=lst20

# %%
DAV_LAP8.head()
# Out:
#    Time  Distance Logger_Temperature AccelerometerX  AccelerometerY  \
# 0  0.00     0.000         29.033.611      -0.127022       -0.080426
# 1  0.05     0.001         29.037.485      -0.323807       -0.098249
# 2  0.10     0.002         29.041.357      -0.509733       -0.116959
# 3  0.15     0.003         29.045.229      -0.669747       -0.133199
# 4  0.20     0.004         29.049.103      -0.792629       -0.147358
#
#    AccelerometerZ     GyroX  GyroY  GyroZ  Int_Batt_Voltage    RPM  \
# 0       -0.943003 -0.675442 -3.577 -1.664             3.777  8.520
# 1       -0.872662 -0.726767 -4.111 -2.250             3.777  8.356
# 2       -0.805965 -0.781491 -4.221 -2.821             3.778  8.231
# 3       -0.748346 -0.827250 -3.947 -3.330             3.779  8.213
# 4       -0.701764 -0.838238 -3.369 -3.721             3.779  8.225
#
#    Calculated_Gear  GPS_Speed  GPS_Nsat  GPS_LatAcc  GPS_LonAcc  GPS_Slope  \
# ...

# %%
lst21=[]
GPS_Longitude=DAV_LAP8.GPS_Longitude.apply(lambda x: float(x.replace('.', '')[0]+'.'+x.replace('.', '')[1:])).values
for i in GPS_Longitude:
    lst21.append(i)
lst21[:10]
# Out:
# [1.688812912392,
#  1.688824823636,
#  1.68883640114,
#  1.688847657624,
#  1.688858619112,
#  1.688869304102,
#  1.688879716266,
#  1.688889870392,
#  1.688899775932,
#  1.688909454859]

# %%
DAV_LAP8['GPS_Longitude']=lst21

# %%
DAV_LAP8.head()
# Out:
#    Time  Distance Logger_Temperature AccelerometerX  AccelerometerY  \
# 0  0.00     0.000         29.033.611      -0.127022       -0.080426
# 1  0.05     0.001         29.037.485      -0.323807       -0.098249
# 2  0.10     0.002         29.041.357      -0.509733       -0.116959
# 3  0.15     0.003         29.045.229      -0.669747       -0.133199
# 4  0.20     0.004         29.049.103      -0.792629       -0.147358
#
#    AccelerometerZ     GyroX  GyroY  GyroZ  Int_Batt_Voltage    RPM  \
# 0       -0.943003 -0.675442 -3.577 -1.664             3.777  8.520
# 1       -0.872662 -0.726767 -4.111 -2.250             3.777  8.356
# 2       -0.805965 -0.781491 -4.221 -2.821             3.778  8.231
# 3       -0.748346 -0.827250 -3.947 -3.330             3.779  8.213
# 4       -0.701764 -0.838238 -3.369 -3.721             3.779  8.225
#
#    Calculated_Gear  GPS_Speed  GPS_Nsat  GPS_LatAcc  GPS_LonAcc  GPS_Slope  \
# ...

# %%
DAV_LAP8.to_csv('../../../Desktop/DAV_LAP8.csv')
