# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.collections import LineCollection
from matplotlib import cm
from scipy import stats as st

import warnings
warnings.filterwarnings('ignore')  

pd.set_option('display.max_columns', None)
import pylab as plt
# import matplotlib.pyplot as plt

plt.rcParams['figure.figsize']=(15, 8)   # tamaño por defecto, decenas de pixeles

import seaborn as sns

# %%
AL_LAP1 = pd.read_csv('../../../Desktop/MA22RT_PROJECT/laps_database/DIVISION2/FSS_ENDURANCE_ALBA_LAP_1.csv', encoding='latin1',sep=';')

# %%
AL_LAP1
# Out:
#        Time  Distance Logger_Temperature  AccelerometerX AccelerometerY  \
# 0      0.00     0.000         33.687.458        0.336049      -0.030920
# 1      0.05     0.001         33.687.458        0.280212      -0.037097
# 2      0.10     0.001         33.687.458        0.217850      -0.046059
# 3      0.15     0.002         33.687.458        0.153605      -0.055294
# 4      0.20     0.003         33.687.458        0.078337      -0.067040
# ...     ...       ...                ...             ...            ...
# 1932  96.60     1.379         33.687.458        0.394342      -0.052449
# 1933  96.65     1.380         33.687.458        0.315895      -0.040060
# 1934  96.70     1.381         33.687.458        0.223167      -0.035256
# 1935  96.75     1.382         33.687.458        0.117918      -0.038079
# 1936  96.77     1.382         33.687.458        0.072057      -0.040659
#
#      AccelerometerZ      GyroX       GyroY       GyroZ Int_Batt_Voltage  \
# ...

# %%
AL_LAP1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1937 entries, 0 to 1936
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time                1937 non-null   float64
#  1   Distance            1937 non-null   float64
#  2   Logger_Temperature  1937 non-null   object
#  3   AccelerometerX      1937 non-null   float64
#  4   AccelerometerY      1937 non-null   object
#  5   AccelerometerZ      1937 non-null   object
#  6   GyroX               1937 non-null   object
#  7   GyroY               1937 non-null   object
#  8   GyroZ               1937 non-null   object
#  9   Int_Batt_Voltage    1937 non-null   object
#  10  RPM                 1937 non-null   object
#  11  Calculated_Gear     1937 non-null   object
#  12  GPS_Speed           1937 non-null   object
#  13  GPS_Nsat            1937 non-null   object
#  14  GPS_LatAcc          1937 non-null   object
# ...

# %%
AL_LAP1.to_csv('../../../Desktop/AL_LAP1.csv')

# %%
AL_LAP1
# Out:
#        Time  Distance Logger_Temperature  AccelerometerX AccelerometerY  \
# 0      0.00     0.000         33.687.458        0.336049      -0.030920
# 1      0.05     0.001         33.687.458        0.280212      -0.037097
# 2      0.10     0.001         33.687.458        0.217850      -0.046059
# 3      0.15     0.002         33.687.458        0.153605      -0.055294
# 4      0.20     0.003         33.687.458        0.078337      -0.067040
# ...     ...       ...                ...             ...            ...
# 1932  96.60     1.379         33.687.458        0.394342      -0.052449
# 1933  96.65     1.380         33.687.458        0.315895      -0.040060
# 1934  96.70     1.381         33.687.458        0.223167      -0.035256
# 1935  96.75     1.382         33.687.458        0.117918      -0.038079
# 1936  96.77     1.382         33.687.458        0.072057      -0.040659
#
#      AccelerometerZ      GyroX       GyroY       GyroZ Int_Batt_Voltage  \
# ...
