# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.collections import LineCollection
from matplotlib import cm

import warnings
warnings.filterwarnings('ignore')  

pd.set_option('display.max_columns', None)

# %%
# estos datos pertenecen a la carrera de Formula Student Netherlands, la primera carrera de la temporada
#para compararla con la primera

# %% [markdown]
# # IMPORT DATA

# %%
FLD = pd.read_csv('../../../Desktop/fsn_david_fastest_lap_juls copia.csv', encoding='latin1', sep=';')

# %%
FLD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3567 entries, 0 to 3566
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Distance            3567 non-null   float64
#  1   Logger_Temperature  3567 non-null   object
#  2   AccelerometerX      3567 non-null   object
#  3   AccelerometerY      3567 non-null   object
#  4   AccelerometerZ      3567 non-null   object
#  5   GyroX               3567 non-null   object
#  6   GyroY               3567 non-null   object
#  7   GyroZ               3567 non-null   object
#  8   Int Batt Voltage    3567 non-null   object
#  9   RPM                 3567 non-null   object
#  10  Calculated_Gear     3567 non-null   object
#  11  GPS_Speed           3567 non-null   object
#  12  GPS_Nsat            3567 non-null   object
#  13  GPS_LatAcc          3567 non-null   object
#  14  GPS_LonAcc          3567 non-null   float64
# ...

# %%
FLD.rename(columns={ 'Int Batt Voltage':'Int_Batt_Voltage'},
               inplace=True)
FLD.columns
# Out:
# Index(['Distance', 'Logger_Temperature', 'AccelerometerX', 'AccelerometerY',
#        'AccelerometerZ', 'GyroX', 'GyroY', 'GyroZ', 'Int_Batt_Voltage', 'RPM',
#        'Calculated_Gear', 'GPS_Speed', 'GPS_Nsat', 'GPS_LatAcc', 'GPS_LonAcc',
#        'GPS_Slope', 'GPS_Heading', 'GPS_Gyro', 'GPS_Altitude',
#        'GPS_PosAccuracy', 'GPS_SpdAccuracy', 'GPS_Latitude', 'GPS_Longitude',
#        'GPS_Elevation'],
#       dtype='object')

# %%
lst=[]

for x in FLD.Logger_Temperature:
    
    lst.append(float('.'.join(x.split('.')[:2])))

    
lst1=[]

for x in FLD.AccelerometerY:
    
    lst1.append(float('.'.join(x.split('.')[:2])))

    
lst2=[]

for x in FLD.AccelerometerZ:
    
    lst2.append(float('.'.join(x.split('.')[:2])))

lst3=[]

for x in FLD.GyroX:
    
    lst3.append(float('.'.join(x.split('.')[:2])))

lst4=[]

for x in FLD.GyroY:
    
    lst4.append(float('.'.join(x.split('.')[:2])))
    
lst5=[]

for x in FLD.GyroZ:
    
    lst5.append(float('.'.join(x.split('.')[:2])))



lst6=[]

for x in FLD.Int_Batt_Voltage:
    
    lst6.append(float('.'.join(x.split('.')[:2])))
    
lst7=[]

for x in FLD.RPM:
    
    lst7.append(float('.'.join(x.split('.')[:2])))
    

    
lst8=[]

for x in FLD.Calculated_Gear:
    
    lst8.append(float('.'.join(x.split('.')[:2])))

    
    
lst9=[]

for x in FLD.GPS_Speed:
    
    lst9.append(float('.'.join(x.split('.')[:2])))
    

lst10=[]

for x in FLD.GPS_Nsat:
    
    lst10.append(float('.'.join(x.split('.')[:2])))

lst11=[]

for x in FLD.GPS_LatAcc:
    
    lst11.append(float('.'.join(x.split('.')[:2])))
    
#lst12=[]

#for x in FLD.GPS_LonAcc:
    
   # lst12.append(float('.'.join(x.split('.')[:2])))
    
    
    
lst13=[]

for x in FLD.GPS_Slope:
    
    lst13.append(float('.'.join(x.split('.')[:2])))
    
    
    
    
lst14=[]

for x in FLD.GPS_Heading:
    
    lst14.append(float('.'.join(x.split('.')[:2])))
    
    
    
lst15=[]

for x in FLD.GPS_Gyro:
    
    lst15.append(float('.'.join(x.split('.')[:2])))
    
 
  
    
lst16=[]

for x in FLD.GPS_PosAccuracy:
    
    lst16.append(float('.'.join(x.split('.')[:2])))  
    

lst17=[]

for x in FLD.GPS_Altitude:
    
    lst17.append(float('.'.join(x.split('.')[:2])))  

    


    
#ALB_LAP5.GPS_Latitude.apply(lambda x: float(x.replace('.', '')[:2]+'.'+x.replace('.', '')[2:])).values
    




#ALB_LAP5.GPS_Longitude.apply(lambda x: float(x.replace('.', '')[0]+'.'+x.replace('.', '')[1:])).values
    
    
lst18=[]

for x in FLD.GPS_Heading:
    
    lst18.append(float('.'.join(x.split('.')[:2])))

# %%
FLD['AccelerometerY']=lst1
FLD['AccelerometerZ']=lst2
FLD['GyroX']=lst3
FLD['GyroY']=lst4
FLD['GyroZ']=lst5
FLD['Int_Batt_Voltage']=lst6
FLD['RPM']=lst7
FLD['Calculated_Gear']=lst8
FLD['GPS_Speed']=lst9
FLD['GPS_Nsat']=lst10
FLD['GPS_LatAcc']=lst11
#FLD['GPS_LonAcc']=lst12
FLD['GPS_Slope']=lst13
FLD['GPS_Gyro']=lst14
FLD['GPS_PosAccuracy']=lst15
FLD['GPS_SpdAccuracy']=lst16
FLD['GPS_Altitude']=lst17
FLD['GPS_Heading']=lst18

# %%
FLD.head()
# Out:
#    Distance Logger_Temperature AccelerometerX  AccelerometerY  AccelerometerZ  \
# 0     0.000         23.187.500      -0.566821        0.812918       -0.850787
# 1     0.000         23.187.500      -0.556435        0.831707       -0.851063
# 2     0.000         23.187.500      -0.548495        0.845669       -0.850612
# 3     0.000         23.187.500      -0.543235        0.855103       -0.849662
# 4     0.001         23.187.500      -0.540204        0.861154       -0.848688
#
#     GyroX  GyroY   GyroZ  Int_Batt_Voltage    RPM  Calculated_Gear  GPS_Speed  \
# 0   7.048 -1.285  33.097             3.952  3.886              6.0     25.302
# 1   8.177 -1.511  35.503             3.952  3.975              6.0     25.281
# 2   9.217 -1.723  37.717             3.952  4.320              6.0     25.261
# 3  10.166 -1.914  39.742             3.952  4.475              6.0     25.241
# 4  11.023 -2.082  41.594             3.952  4.578              6.0     25.221
#
# ...

# %%
lst20=[]
GPS_Latitude=FLD.GPS_Latitude.apply(lambda x: float(x.replace('.', '')[:2]+'.'+x.replace('.', '')[2:])).values
for i in GPS_Latitude:
    lst20.append(i)
lst20[:20]
# Out:
# [52.957134999531,
#  52.957134224269,
#  52.957133465961,
#  52.957132747212,
#  52.957132028463,
#  52.957131359048,
#  52.957130701967,
#  52.957130064974,
#  52.957129474855,
#  52.957128884736,
#  52.9571283488,
#  52.957127826411,
#  52.957127322664,
#  52.957126862415,
#  52.957126402166,
#  52.957125981323,
#  52.957125570332,
#  52.957125167829,
#  52.957124785129,
#  52.957124402429]

# %%
FLD['GPS_Latitude']=lst20

# %%
lst21=[]
GPS_Longitude=FLD.GPS_Longitude.apply(lambda x: float(x.replace('.', '')[0]+'.'+x.replace('.', '')[1:])).values
for i in GPS_Longitude:
    lst21.append(i)
lst21[:10]
# Out:
# [6.525579038428,
#  6.525577400807,
#  6.525575743675,
#  6.525574041014,
#  6.525572338354,
#  6.525570596129,
#  6.525568844013,
#  6.525567081551,
#  6.525565294948,
#  6.525563508344]

# %%
FLD['GPS_Longitude']=lst21

# %%
FLD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3567 entries, 0 to 3566
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Distance            3567 non-null   float64
#  1   Logger_Temperature  3567 non-null   object
#  2   AccelerometerX      3567 non-null   object
#  3   AccelerometerY      3567 non-null   float64
#  4   AccelerometerZ      3567 non-null   float64
#  5   GyroX               3567 non-null   float64
#  6   GyroY               3567 non-null   float64
#  7   GyroZ               3567 non-null   float64
#  8   Int_Batt_Voltage    3567 non-null   float64
#  9   RPM                 3567 non-null   float64
#  10  Calculated_Gear     3567 non-null   float64
#  11  GPS_Speed           3567 non-null   float64
#  12  GPS_Nsat            3567 non-null   float64
#  13  GPS_LatAcc          3567 non-null   float64
#  14  GPS_LonAcc          3567 non-null   float64
# ...

# %%
lst22=[]

for x in FLD.AccelerometerX:
    
    lst22.append(float('.'.join(x.split('.')[:2])))

# %%
FLD['AccelerometerX']=lst22

# %%
lst23=[]

for x in FLD.Logger_Temperature:
    
    lst23.append(float('.'.join(x.split('.')[:2])))

# %%
FLD['Logger_Temperature']=lst23

# %%
FLD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3567 entries, 0 to 3566
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Distance            3567 non-null   float64
#  1   Logger_Temperature  3567 non-null   float64
#  2   AccelerometerX      3567 non-null   float64
#  3   AccelerometerY      3567 non-null   float64
#  4   AccelerometerZ      3567 non-null   float64
#  5   GyroX               3567 non-null   float64
#  6   GyroY               3567 non-null   float64
#  7   GyroZ               3567 non-null   float64
#  8   Int_Batt_Voltage    3567 non-null   float64
#  9   RPM                 3567 non-null   float64
#  10  Calculated_Gear     3567 non-null   float64
#  11  GPS_Speed           3567 non-null   float64
#  12  GPS_Nsat            3567 non-null   float64
#  13  GPS_LatAcc          3567 non-null   float64
#  14  GPS_LonAcc          3567 non-null   float64
# ...

# %%
FLD.to_csv('../../../Desktop/FLD.csv', index=False)
